# %%
import os
import isx
import time

INPUT_DIRECTORY_NAME = r'\\172.16.251.125\Inscopix\Francesco\H2235 - 4X\H2235_4X_EGO\H2235_4X_EGO_LR\H2235_4X_EGO_LR_data'#
OUTPUT_DIRECTORY_NAME = r'\\172.16.251.125\Inscopix\Francesco\H2235 - 4X\H2235_4X_EGO\CNMFe-SET\CNMFe-SET2' # <----INPUT the directory location in which your files are being stored
report_name='H2235_4X_EGO_2023_08_07.txt'

# Input stage as the dictionary key, then list MC recordings
series_rec_names = {

    '30 cho':
['2021-04-28-10-03-01_video-PP-BP-MC-MC-TPC',
 '2021-04-28-10-06-54_video-PP-BP-MC-MC-TPC',
 '2021-04-28-10-09-59_video-PP-BP-MC-MC-TPC',
 '2021-04-28-10-13-20_video-PP-BP-MC-MC-TPC']
      
       
        }

#Dictionary of parameter sets
parameter_sets = {
    1:
        {
        'num_processes':1, 
        'K':40 , 
        'decay_time': 0.4, 
        'rf':50, #[50,50] 
        'stride':25, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':5, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':25, 
        'min_corr':0.8, 
        'event_threshold':0.4,
        'merge_threshold':0.8
        }, 
     2:
        {
        'num_processes':1, 
        'K':40 , 
        'decay_time': 0.4, 
        'rf':50, #[50,50]
        'stride':25, 
        'gSig':6, 
        'gSiz':20, 
        'min_SNR':5, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':25, 
        'min_corr':0.9, 
        'event_threshold':0.4,
        'merge_threshold':0.8
        }, 
     3:
        {
        'num_processes':1, 
        'K':40 , 
        'decay_time': 0.4, 
        'rf':50, #[50,50]
        'stride':25, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':10, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':25, 
        'min_corr':0.8, 
        'event_threshold':0.4,
        'merge_threshold':0.8
        }, 
     4:
        {
        'num_processes':1, 
        'K':40 , 
        'decay_time': 0.4, 
        'rf':50, #[50,50]
        'stride':25, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':10, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':30, 
        'min_corr':0.9, 
        'event_threshold':0.4,
        'merge_threshold':0.8
        }, 
     5:
        {
        'num_processes':1, 
        'K':40 , 
        'decay_time': 0.4, 
        'rf':50, #[50,50]
        'stride':25, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':10, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':30, 
        'min_corr':0.9, 
        'event_threshold':0.4,
        'merge_threshold':0.6
        }, 
     6:
        {
        'num_processes':1, 
        'K':40 , 
        'decay_time': 0.4, 
        'rf':50, #[50,50] 
        'stride':25, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':20, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':30, 
        'min_corr':0.9, 
        'event_threshold':0.4,
        'merge_threshold':0.6
        }, 
     7:
        {
        'num_processes':1, 
        'K':40 , 
        'decay_time': 0.4, 
        'rf':50, #[50,50]
        'stride':25, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':20, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':35, 
        'min_corr':0.7, 
        'event_threshold':0.4,
        'merge_threshold':0.6
        }, 
     8:
        {
        'num_processes':1, 
        'K':160 , 
        'decay_time': 0.4, 
        'rf':100, #[100,100]
        'stride':75, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':20, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':30, 
        'min_corr':0.9, 
        'event_threshold':0.4,
        'merge_threshold':0.6
        }, 
     9:
        {
        'num_processes':1, 
        'K':160 , 
        'decay_time': 0.4, 
        'rf':20, #[20,20]
        'stride':5, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':20, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':30, 
        'min_corr':0.9, 
        'event_threshold':0.2,
        'merge_threshold':0.6
        }, 
     10:
        {
        'num_processes':1, 
        'K':200 , 
        'decay_time': 0.4, 
        'rf':100, #[100,100]
        'stride':75, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':20, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':20, 
        'min_corr':0.9, 
        'event_threshold':0.5,
        'merge_threshold':0.6
        }, 
     11:
        {
        'num_processes':1, 
        'K':200 , 
        'decay_time': 0.4, 
        'rf':100, #[100,100]
        'stride':75, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':20, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':25, 
        'min_corr':0.9, 
        'event_threshold':0.3,
        'merge_threshold':0.6
        }, 
     12:
        {
        'num_processes':1, 
        'K':250 , 
        'decay_time': 0.4, 
        'rf':100, #[100,100]
        'stride':75, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':20, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':15, 
        'min_corr':0.9, 
        'event_threshold':0.5,
        'merge_threshold':0.6
        }, 
     13:
        {
        'num_processes':1, 
        'K':250 , 
        'decay_time': 0.4, 
        'rf':100, #[100,100]
        'stride':75, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':20, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':15, 
        'min_corr':0.85, 
        'event_threshold':0.3,
        'merge_threshold':0.6
        }, 
     14:
        {
        'num_processes':1, 
        'K':40 , 
        'decay_time': 0.4, 
        'rf':50, #[50,50]
        'stride':25, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':10, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':30, 
        'min_corr':0.9, 
        'event_threshold':0.4,
        'merge_threshold':0.6
        }, 
     15:
        {
        'num_processes':1, 
        'K':40 , 
        'decay_time': 0.4, 
        'rf':20, #[20,20]
        'stride':15, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':20, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':30, 
        'min_corr':0.9, 
        'event_threshold':0.5,
        'merge_threshold':0.6
        }, 
     16:
        {
        'num_processes':1, 
        'K':40 , 
        'decay_time': 0.4, 
        'rf':20, #[20,20] 
        'stride':15, 
        'gSig':5, 
        'gSiz':10, 
        'min_SNR':20, 
        'rval_thr':0.85, 
        'ssub_B':1, 
        'min_pnr':20, 
        'min_corr':0.9, 
        'event_threshold':0.5,
        'merge_threshold':0.6
        }, 
    }        

                
#rf 
#while loop through parameter sets, output file appended with parameter set label 
i=1
for i in [12]: 
        print(i)
        #sets each parameter to the relevant value in the dictionary        
        num_processes=parameter_sets[i]['num_processes']
        K=parameter_sets[i]['K']
        decay_time=parameter_sets[i]['decay_time']
        rf=parameter_sets[i]['rf']
        stride=parameter_sets[i]['stride']
        gSig=parameter_sets[i]['gSig']
        gSiz=parameter_sets[i]['gSiz']
        min_SNR=parameter_sets[i]['min_SNR']
        rval_thr=parameter_sets[i]['rval_thr']
        ssub_B=parameter_sets[i]['ssub_B']
        stride=parameter_sets[i]['stride']
        min_pnr=parameter_sets[i]['min_pnr']
        min_corr=parameter_sets[i]['min_corr']
        event_threshold=parameter_sets[i]['event_threshold']
        merge_threshold=parameter_sets[i]['merge_threshold']
        #export file ends in i        
        INPUT_TRIAL=i  #<---- trial number (change if altering the parameters)

        for series_name, rec_names in series_rec_names.items():
            # Create lists of all files processed up to motion correction
            mov_files = [os.path.join(INPUT_DIRECTORY_NAME, name + '.isxd') for name in rec_names]

            # Create output file names
            cellset_files = [os.path.join(OUTPUT_DIRECTORY_NAME, name +'-CNMFE-p'+str(INPUT_TRIAL)+'.isxd') for name in rec_names]
            events_files = [os.path.join(OUTPUT_DIRECTORY_NAME, name +'-CNMFE-ED-p'+str(INPUT_TRIAL)+'.isxd') for name in rec_names]

            # remove output files if they already exist
            for cellset_file, events_file in zip(cellset_files, events_files):
                if os.path.exists(cellset_file):
                    os.remove(cellset_file)
                if os.path.exists(events_file):
                    os.remove(events_file)

            #report
            f=open(os.path.join(OUTPUT_DIRECTORY_NAME , report_name), "a+")
            text=["File : ", str(mov_files), "\n"]
            f.writelines(text)
            f.write=('Parameter set %s \n' % i)
            f.write=("K: \t %s\n" % K)
            f.write=("rf: \t %s\n" % rf)
            f.write=("stride: \t %s\n" % stride)
            f.write=("gSig: \t %s\n" % gSig)
            f.write=("gSiz: \t %s\n" % gSiz)
            f.write=("min_SNR: \t %s\n" % min_SNR)
            f.write=("min_pnr: \t %s\n" % min_pnr)
            f.write=("rval_thr: \t %s\n" % rval_thr)
            f.write=("min_corr: \t %s\n" % min_corr)
            f.write=("event_threshold: \t %s\n" % event_threshold)
            f.write=("merge_threshold: \t %s\n" % merge_threshold)
            f.close()
            
            print("Parameters saved to output folder")
                    
                    
            # Run CNMF-E
            start = time.time()
            print('Analysing', cellset_files)
            isx.run_cnmfe(mov_files, cellset_files, INPUT_DIRECTORY_NAME,
                          cell_diameter=gSiz,
                          min_corr=min_corr,
                          min_pnr=min_pnr,
                          bg_spatial_subsampling=2,
                          ring_size_factor=1.4,
                          gaussian_kernel_size=gSig,
                          closing_kernel_size=0,
                          merge_threshold=merge_threshold,
                          processing_mode='parallel_patches',
                          num_threads=4,
                          patch_size=rf,
                          patch_overlap=stride,
                          output_unit_type='scaled_df'
                          )



            end = time.time()
            print('run_cnmfe - complete,', 'Time -elapsed =', ((end-start)/60)/60)
            
            f=open(os.path.join(OUTPUT_DIRECTORY_NAME , report_name), "a+")
            text2='Run Time = '+ str(((end-start)/60)/60)+ "\n \n --------------------------"
            f.write=(text2)
            f.close()
        i+=1
# Out:
# 12
# Parameters saved to output folder
# Analysing ['\\\\172.16.251.125\\Inscopix\\Francesco\\H2235 - 4X\\H2235_4X_EGO\\CNMFe-SET\\CNMFe-SET2\\2021-04-28-10-03-01_video-PP-BP-MC-MC-TPC-CNMFE-p12.isxd', '\\\\172.16.251.125\\Inscopix\\Francesco\\H2235 - 4X\\H2235_4X_EGO\\CNMFe-SET\\CNMFe-SET2\\2021-04-28-10-06-54_video-PP-BP-MC-MC-TPC-CNMFE-p12.isxd', '\\\\172.16.251.125\\Inscopix\\Francesco\\H2235 - 4X\\H2235_4X_EGO\\CNMFe-SET\\CNMFe-SET2\\2021-04-28-10-09-59_video-PP-BP-MC-MC-TPC-CNMFE-p12.isxd', '\\\\172.16.251.125\\Inscopix\\Francesco\\H2235 - 4X\\H2235_4X_EGO\\CNMFe-SET\\CNMFe-SET2\\2021-04-28-10-13-20_video-PP-BP-MC-MC-TPC-CNMFE-p12.isxd']
# run_cnmfe - complete, Time -elapsed = 1.2953070372343063

# %%
import os
import isx
import time

INPUT_DIRECTORY_NAME = r'\\172.16.251.125\Inscopix\Francesco\H2235 - 4X\H2235_4X_EGO\H2235_4X_EGO_LR\H2235_4X_EGO_LR_data' #
videos=[]
for (dirpath, dirnames, filenames) in os.walk(INPUT_DIRECTORY_NAME):
    for file in filenames:
        if file[-7:]=="MC.isxd":
            videos.append(file)

# %%
videos.sort()
videos
# Out:
# ['2021-04-28-10-03-01_video-PP-BP-MC-MC.isxd',
#  '2021-04-28-10-06-54_video-PP-BP-MC-MC.isxd',
#  '2021-04-28-10-09-59_video-PP-BP-MC-MC.isxd',
#  '2021-04-28-10-13-20_video-PP-BP-MC-MC.isxd']
