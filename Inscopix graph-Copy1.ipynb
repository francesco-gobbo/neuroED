# %%
import os
import isx
import time
import numpy
import pandas as pd
import matplotlib.pyplot as plt

folder_cellset = r'\\172.16.251.125\Inscopix\Francesco\H0466 - 4X/H0466_123_ALL_1234X\H0466_123_ALL_1234X_CNMFe_11.3_12.3' 
folder_events = r'\\172.16.251.125\Inscopix\Francesco\for maps - temp\H0466\H0466_data'
FILE_NAME='2019-06-19-15-30-27_video-PP-PP-BP-MC_001-MC-CNMFE-4X_11.30.isxd'
events_name='2019-06-19-15-30-27_video-PP-PP-BP-MC_001-MC-CNMFE-4X_11-ED.isxd'
# Input stage as the dictionary key, then list MC recordings
cellset_file = os.path.join(folder_cellset, FILE_NAME)
events_file= os.path.join(folder_events, events_name)
metrics_file = os.path.join(folder_events, 'H0466_A01_PRE_metrics.csv')

if not os.path.exists(metrics_file):
                            isx.cell_metrics(cellset_file, events_file, metrics_file)

metrics_df = pd.read_csv(metrics_file)
cellset = isx.CellSet.read(cellset_file)
accepted_cells = [cellset.get_cell_name(k) for k in range(cellset.num_cells) if cellset.get_cell_status(k) == 'accepted']

# Create a logical index that only references accepted cells with reasonable SNRs.
accept_i = metrics_df.cellName.isin(accepted_cells) & (metrics_df.snr > 1)

# %%
import os
import isx
import time
import numpy
import pandas as pd
import matplotlib.pyplot as plt

folder_cellset = r'\\172.16.251.125\Inscopix\Francesco\H2202 -2\H2202_456_ALL_456_4x\H2202_456_ALL_456_CNMFe\CNMFe_9.2_and_11.2' 
folder_events = r'\\172.16.251.125\Inscopix\Francesco\H2202 -2\H2202_456_ALL_456_4x\H2202_456_ALL_456_4x_data'
FILE_NAME='2019-10-21-11-30-08_video-PP-PP-BP-MC-CNMFE-4X_9_20.isxd'
events_name='2019-10-21-11-30-08_video-PP-PP-BP-MC-CNMFE-4X_9_20-ED.isxd'
# Input stage as the dictionary key, then list MC recordings
cellset_file = os.path.join(folder_cellset, FILE_NAME)
events_file= os.path.join(folder_events, events_name)
metrics_file = os.path.join(folder_events, 'H0466_A01_PRE_metrics.csv')

if not os.path.exists(metrics_file):
                            isx.cell_metrics(cellset_file, events_file, metrics_file)

metrics_df = pd.read_csv(metrics_file)
cellset = isx.CellSet.read(cellset_file)
accepted_cells = [cellset.get_cell_name(k) for k in range(cellset.num_cells) if cellset.get_cell_status(k) == 'accepted']

# Create a logical index that only references accepted cells with reasonable SNRs.
accept_i = metrics_df.cellName.isin(accepted_cells) & (metrics_df.snr > 1)

# %%
import os
import isx
import time
import numpy
import pandas as pd
import matplotlib.pyplot as plt

folder_cellset = r'\\172.16.251.125\Inscopix\Francesco\H2203\H2203_ALL_123_ALL_4x\CNMFe' 
folder_events = r'\\172.16.251.125\Inscopix\Francesco\H2203\H2203_ALL_123_ALL_4x\H2203_ALL_123_ALL_4x_data'
FILE_NAME='2019-10-21-18-02-08_video-PP-PP_001-BP-MC-CNMFE-4X_18.isxd'
events_name='2019-10-21-18-02-08_video-PP-PP_001-BP-MC-CNMFE-4X_18-ED.isxd'
# Input stage as the dictionary key, then list MC recordings
cellset_file = os.path.join(folder_cellset, FILE_NAME)
events_file= os.path.join(folder_events, events_name)
metrics_file = os.path.join(folder_events, 'H0466_A01_PRE_metrics.csv')

if not os.path.exists(metrics_file):
                            isx.cell_metrics(cellset_file, events_file, metrics_file)

metrics_df = pd.read_csv(metrics_file)
cellset = isx.CellSet.read(cellset_file)
accepted_cells = [cellset.get_cell_name(k) for k in range(cellset.num_cells) if cellset.get_cell_status(k) == 'accepted']

# Create a logical index that only references accepted cells with reasonable SNRs.
accept_i = metrics_df.cellName.isin(accepted_cells) & (metrics_df.snr > 1)

# %%
import os
import isx
import time
import numpy
import pandas as pd
import matplotlib.pyplot as plt

folder_cellset = r'\\172.16.251.125\Inscopix\Francesco\H0487 - 4X\H0487_123_ALL_23_4x\H0487_123_ALL_123_CNMFe\H0487_123_ALL_123_CNMFe_13_and_17' 
folder_events = r'\\172.16.251.125\Inscopix\Francesco\H0487 - 4X\H0487_123_ALL_23_4x\H0487_123_ALL_23_4x_data'
FILE_NAME='2019-07-22-10-40-52_video-PP-PP-BP-MC-CNMFE-4X_13.30.isxd'
events_name='2019-07-22-10-40-52_video-PP-PP-BP-MC-CNMFE-4X_13-ED.isxd'
# Input stage as the dictionary key, then list MC recordings
cellset_file = os.path.join(folder_cellset, FILE_NAME)
events_file= os.path.join(folder_events, events_name)
metrics_file = os.path.join(folder_events, 'H0466_A01_PRE_metrics.csv')

if not os.path.exists(metrics_file):
                            isx.cell_metrics(cellset_file, events_file, metrics_file)

metrics_df = pd.read_csv(metrics_file)
cellset = isx.CellSet.read(cellset_file)
accepted_cells = [cellset.get_cell_name(k) for k in range(cellset.num_cells) if cellset.get_cell_status(k) == 'accepted']

# Create a logical index that only references accepted cells with reasonable SNRs.
accept_i = metrics_df.cellName.isin(accepted_cells) & (metrics_df.snr > 1)

# %%
import os
import isx
import time
import numpy
import pandas as pd
import matplotlib.pyplot as plt

folder_cellset = r'\\172.16.251.125\Inscopix\Francesco\H0465 - 4x\H0465_123_ALL_1234X\H0465_123_ALL_1234X_CNMFe_11.3-17.3' 
folder_events = r'\\172.16.251.125\Inscopix\Francesco\H0465 - 4x\H0465_123_ALL_1234X\H0465_123_ALL_1234X_data'
FILE_NAME='2019-06-19-14-55-21_video-PP-PP-BP-MC-CNMFE-4X_11.30.isxd'
events_name='2019-06-19-14-55-21_video-PP-PP-BP-MC-CNMFE-4X_11-ED.isxd'
# Input stage as the dictionary key, then list MC recordings
cellset_file = os.path.join(folder_cellset, FILE_NAME)
events_file= os.path.join(folder_events, events_name)
metrics_file = os.path.join(folder_events, 'H0466_A01_PRE_metrics.csv')

if not os.path.exists(metrics_file):
                            isx.cell_metrics(cellset_file, events_file, metrics_file)

metrics_df = pd.read_csv(metrics_file)
cellset = isx.CellSet.read(cellset_file)
accepted_cells = [cellset.get_cell_name(k) for k in range(cellset.num_cells) if cellset.get_cell_status(k) == 'accepted']

# Create a logical index that only references accepted cells with reasonable SNRs.
accept_i = metrics_df.cellName.isin(accepted_cells) & (metrics_df.snr > 1)

# %%
for i in metrics_df.index:
    if metrics_df.loc[i, 'eventRate']>0.1:
        metrics_df.loc[i, 'eventRate']=0.1
        
for i in metrics_df.index:
   if metrics_df.loc[i, 'snr']>250:
       metrics_df.loc[i, 'snr']=250

# %%
circle_size = metrics_df[accept_i]['snr'] 
plt.figure( figsize=(8,5),dpi=1000)
plt.scatter(metrics_df[accept_i]['largestComponentCenterInPixelsX'],
metrics_df[accept_i]['largestComponentCenterInPixelsY'],
c=metrics_df[accept_i]['eventRate'], s=circle_size,
cmap=plt.cm.rainbow)
plt.colorbar()
plt.ylim((-10,200))
plt.xlim((-10,250));
plt.savefig(os.path.join(r'C:\Users\fgobbo\OneDrive - University of Edinburgh\arena room files\ANALYSIS 1.0\Field of View Images\maps accepted cells', 'H2203_A01_PRE_map.eps'), dpi=1000)

# %%
plt.figure( figsize=(8,5),dpi=1000)
plt.scatter([3*i for i in [2, 5, 10, 15, 20,  30,40]],
[100,100,100,100,100,100,100],marker='o',edgecolors='k',c='white', linewidth=1,
s=[5,10,25,50,100,175, 250])
plt.ylim((-10,200))
plt.xlim((-10,250));
plt.colorbar()
plt.savefig(os.path.join(r'C:\Users\fgobbo\OneDrive - University of Edinburgh\arena room files\ANALYSIS 1.0\Field of View Images\maps accepted cells', 'size legend.eps'), dpi=1000)

# %%
import os
import isx
import time
import numpy
import pandas as pd
import matplotlib.pyplot as plt

folder = r'\\172.16.251.125\Inscopix\Francesco\H0466 - 4X\H0466_123_ALL_1234X\H0466_123_ALL_1234X_data' 
#FILE_NAME='2019-07-22-11-03-46_video-PP-BP-MC.isxd-CNMFE-4X_13.isxd'
# Input stage as the dictionary key, then list MC recordings
cellset_file = r'\\172.16.251.125\Inscopix\Francesco\H0466 - 4X\H0466_123_ALL_1234X\2019-06-19-15-30-27_video-PP-PP-BP-MC_001-MC-CNMFE-4X_11.isxd'
events_file= r'\\172.16.251.125\Inscopix\Francesco\H0466 - 4X\H0466_123_ALL_1234X\H0466_123_ALL_1234X_data\2019-06-19-15-44-09_video-PP-PP-BP-MC_001-MC-CNMFE-4X_12-ED.isxd'
metrics_file = os.path.join(folder, 'H0466_A01_PRE_metrics.csv')

if not os.path.exists(metrics_file):
                            isx.cell_metrics(cellset_file, events_file, metrics_file)

metrics_df = pd.read_csv(metrics_file)
cellset = isx.CellSet.read(cellset_file)
accepted_cells = [cellset.get_cell_name(k) for k in range(cellset.num_cells) if cellset.get_cell_status(k) == 'accepted']

# Create a logical index that only references accepted cells with reasonable SNRs.
accept_i = metrics_df.cellName.isin(accepted_cells) & (metrics_df.snr > 1)

for i in metrics_df.index:
   if metrics_df.loc[i, 'snr']>250:
       metrics_df.loc[i, 'snr']=250

for i in metrics_df.index:
   if metrics_df.loc[i, 'eventRate']>0.10:
       metrics_df.loc[i, 'eventRate']=0.10
        
circle_size = metrics_df[accept_i]['snr'] 
plt.figure( figsize=(8,5),dpi=1000)
fig=plt.scatter(metrics_df[accept_i]['largestComponentCenterInPixelsX'],
metrics_df[accept_i]['largestComponentCenterInPixelsY'],
c=metrics_df[accept_i]['eventRate'], s=circle_size*2,
cmap=plt.cm.rainbow)

plt.ylim((0,200))
plt.xlim((0,250));
plt.colorbar()
plt.show()
plt.savefig(fig, os.path.join(r'C:\Users\fgobbo\OneDrive - University of Edinburgh\arena room files\ANALYSIS 1.0\Field of View Images\maps accepted cells', 'H0466_A01_PRE_map.eps'), dpi=1000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-9fd1be6fd588> in <module>
#      42 plt.colorbar()
#      43 plt.show()
# ---> 44 plt.savefig(fig, os.path.join(r'C:\Users\fgobbo\OneDrive - University of Edinburgh\arena room files\ANALYSIS 1.0\Field of View Images\maps accepted cells', 'H0466_A01_PRE_map.eps'), dpi=1000)
#
# ~\Anaconda3\envs\isxenv\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# TypeError: savefig() takes 2 positional arguments but 3 were given

# %%
metrics_df
# Out:
#     cellName      snr        mad  eventRate  eventAmpMedian  eventAmpSD  \
# 0         C0  39.5140   0.882202   0.277279         34.8593     402.427
# 1         C1  28.4044  19.826800   0.005963        563.1690      69.810
# 2         C2  18.7215  22.304600   0.023852        417.5760     158.738
# 3         C3  29.3008  17.178800   0.050685        503.3520     288.163
# 4         C4  30.6721  46.954900   0.059630       1440.2000     928.246
# ..       ...      ...        ...        ...             ...         ...
# 164     C164   0.0000   0.000000   0.000000          0.0000       0.000
# 165     C165  13.5794  11.423800   0.002982        155.1280       0.000
# 166     C166   0.0000   0.000000   0.000000          0.0000       0.000
# 167     C167  31.9329  15.754500   0.098389        503.0870     497.160
# 168     C168  12.5640  21.382600   0.002982        268.6520       0.000
#
#      riseMedian    riseSD  decayMedian   decaySD  numContourComponents  \
# ...

# %%
circle_size = metrics_df[accept_i]['snr'] 
plt.figure( dpi=1000)
plt.scatter(metrics_df[accept_i]['largestComponentCenterInPixelsX'],
metrics_df[accept_i]['largestComponentCenterInPixelsY'],
c=metrics_df[accept_i]['eventRate'], s=circle_size,
cmap=plt.cm.rainbow)
plt.colorbar()

plt.savefig(os.path.join(r'\\172.16.251.125\Inscopix\Francesco\H2203\H2203_ALL_123_ALL_4x\H2203_ALL_123_ALL_4X_LR\temp', 'H2202_A01_PRE_map.tiff'))
